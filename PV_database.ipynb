# %%
import numpy as np
import pandas as pd
import glob
import os

# %% [markdown]
# ## Synth

# %%
file = 'dataset_old/PCE_47k_191.csv'

# %% [markdown]
# df = pd.read_csv(file, chunksize=100)

# %%
df_synth = pd.read_csv(file)
# Out:
# /usr/local/Caskroom/miniforge/base/envs/env_py39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (2,5,6,8,9,77,181) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_synth.shape
# Out:
# (46707, 182)

# %% [markdown]
# df_test = next(df)

# %%
list(dict(df_synth.iloc[0])).index('H')
# Out:
# 78

# %%
list(dict(df_synth.iloc[0])).index('Lr')
# Out:
# 180

# %%
list(df_synth.columns)
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'material_id',
#  'band_gap',
#  'formula',
#  'structure',
#  'spacegroup',
#  'e_above_hull',
#  'new_formula',
#  'new_formula_1',
#  'composition',
#  'MagpieData minimum MeltingT',
#  'MagpieData maximum MeltingT',
#  'MagpieData range MeltingT',
#  'MagpieData mean MeltingT',
#  'MagpieData avg_dev MeltingT',
#  'MagpieData mode MeltingT',
#  'MagpieData minimum CovalentRadius',
#  'MagpieData maximum CovalentRadius',
#  'MagpieData range CovalentRadius',
#  'MagpieData mean CovalentRadius',
#  'MagpieData avg_dev CovalentRadius',
#  'MagpieData mode CovalentRadius',
#  'MagpieData minimum Electronegativity',
#  'MagpieData maximum Electronegativity',
#  'MagpieData range Electronegativity',
#  'MagpieData mean Electronegativity',
#  'MagpieData avg_dev Electronegativity',
#  'MagpieData mode Electronegativity',
#  'MagpieData minimum NsValence',
#  'MagpieData maximum NsValence',
#  'MagpieData range NsValence',
# ...

# %%
H = 78
Lr = 181

elem = {df_synth.columns[j]:0 for j in range(78,181)}

# %%
for i in range(df_synth.shape[0]):
    for j in range(78, 181):
        if df_synth.iloc[i, j] > 0:
            elem[df_synth.columns[j]]+=1

# %%
elem
# Out:
# {'H': 4135,
#  'He': 0,
#  'Li': 9967,
#  'Be': 208,
#  'B': 1740,
#  'C': 3332,
#  'N': 4032,
#  'O': 31760,
#  'F': 4915,
#  'Ne': 0,
#  'Na': 3588,
#  'Mg': 2279,
#  'Al': 1608,
#  'Si': 3012,
#  'P': 6449,
#  'S': 5114,
#  'Cl': 2931,
#  'Ar': 0,
#  'K': 3315,
#  'Ca': 2354,
#  'Sc': 516,
#  'Ti': 2193,
#  'V': 4401,
#  'Cr': 2456,
#  'Mn': 4421,
#  'Fe': 4322,
#  'Co': 2742,
#  'Ni': 1417,
#  'Cu': 1664,
#  'Zn': 1953,
#  'Ga': 1167,
#  'Ge': 1417,
#  'As': 1619,
#  'Se': 2959,
#  'Br': 1506,
#  'Kr': 10,
#  'Rb': 2019,
#  'Sr': 1987,
#  'Y': 997,
#  'Zr': 720,
#  'Nb': 1420,
#  'Mo': 1934,
#  'Tc': 63,
#  'Ru': 162,
#  'Rh': 185,
#  'Pd': 319,
#  'Ag': 1310,
#  'Cd': 1078,
#  'In': 1102,
#  'Sn': 1605,
#  'Sb': 2045,
#  'Te': 2001,
#  'I': 1807,
#  'Xe': 118,
#  'Cs': 1942,
#  'Ba': 2641,
#  'La': 1448,
#  'Ce': 304,
#  'Pr': 506,
#  'Nd': 672,
#  'Pm': 23,
#  'Sm': 523,
#  'Eu': 98,
#  'Gd': 529,
#  'Tb': 333,
#  'Dy': 394,
#  'Ho': 388,
#  'Er': 387,
#  'Tm': 273,
# ...

# %%
{k: v for k, v in sorted(elem.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'O': 31760,
#  'Li': 9967,
#  'P': 6449,
#  'S': 5114,
#  'F': 4915,
#  'Mn': 4421,
#  'V': 4401,
#  'Fe': 4322,
#  'H': 4135,
#  'N': 4032,
#  'Na': 3588,
#  'C': 3332,
#  'K': 3315,
#  'Si': 3012,
#  'Se': 2959,
#  'Cl': 2931,
#  'Co': 2742,
#  'Ba': 2641,
#  'Cr': 2456,
#  'Ca': 2354,
#  'Mg': 2279,
#  'Ti': 2193,
#  'Sb': 2045,
#  'Rb': 2019,
#  'Te': 2001,
#  'Sr': 1987,
#  'Zn': 1953,
#  'Cs': 1942,
#  'Mo': 1934,
#  'W': 1820,
#  'I': 1807,
#  'B': 1740,
#  'Bi': 1733,
#  'Cu': 1664,
#  'As': 1619,
#  'Al': 1608,
#  'Sn': 1605,
#  'Br': 1506,
#  'La': 1448,
#  'Nb': 1420,
#  'Ni': 1417,
#  'Ge': 1417,
#  'Ag': 1310,
#  'Pb': 1214,
#  'Ga': 1167,
#  'In': 1102,
#  'Cd': 1078,
#  'Y': 997,
#  'Tl': 962,
#  'Ta': 935,
#  'Zr': 720,
#  'Hg': 687,
#  'Nd': 672,
#  'Gd': 529,
#  'Sm': 523,
#  'Sc': 516,
#  'Pr': 506,
#  'Au': 506,
#  'U': 468,
#  'Dy': 394,
#  'Ho': 388,
#  'Er': 387,
#  'Pt': 358,
#  'Tb': 333,
#  'Hf': 326,
#  'Pd': 319,
#  'Re': 314,
#  'Ce': 304,
#  'Lu': 303,
# ...

# %%
df_synth.iloc[0, 72]
# Out:
# 0.0

# %%
list(df_synth['material_id'])[0].split('-')[0]
# Out:
# 'mp'

# %%
dbs = set([str(i).split('-')[0] for i in list(df_synth['material_id'])])
dbs
# Out:
# {'mp', 'mvc', 'nan'}

# %%
df_synth[df_synth['material_id'].isna()]
# Out:
#        Unnamed: 0  Unnamed: 0.1 material_id  band_gap          formula  \
# 44391       44391             0         NaN     1.710  Sm$_{2}$S$_{3}$
# 44392       44392             1         NaN     0.153           Bi2Te3
# 44393       44393             2         NaN     0.567           Mg2Ge1
# 44394       44394             3         NaN     0.045           Co1Si1
# 44395       44395             4         NaN     7.025           Na1Br1
# ...           ...           ...         ...       ...              ...
# 46702       46702          2311         NaN     6.700            Si3N4
# 46703       46703          2312         NaN     7.000            BaCl2
# 46704       46704          2313         NaN     7.500            SrCl2
# 46705       46705          2314         NaN     7.500            MgCl2
# 46706       46706          2315         NaN     6.900            CaCl2
#
#       structure spacegroup  e_above_hull new_formula new_formula_1  ...   Am  \
# ...

# %%
df_synth.loc[44391]['formula']
# Out:
# 'Sm$_{2}$S$_{3}$'

# %% [markdown]
# ## Experimental

# %%
import pandas as pd

# %%
file_exp = 'exp_gaps_2k.csv'

# %% [markdown]
# df = pd.read_csv(file, chunksize=100)

# %%
df_exp = pd.read_csv(file_exp)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/r0/sh_xx3ms6_j0__w1_7f87p540000gq/T/ipykernel_25225/2600260786.py in <module>
# ----> 1 df_exp = pd.read_csv(file_exp)
#
# ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.shape

# %%
df_exp.iloc[0]

# %%
df_exp.columns
